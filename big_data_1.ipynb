# %% [markdown]
# <a href="https://colab.research.google.com/github/venidaydream/Intro_to_Big_Data/blob/main/big_data_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime

# %%
path = "/content/NFLX.xlsx"

# %%
df = pd.read_excel(path,index_col = 0)

# %%
df.head()
df.tail()
df.shape

## adj close is different from close because of the dividends or splits
df2 = df['Adj Close']
df2
# Out:
# Date
# 2020-10-05    520.650024
# 2020-10-06    505.869995
# 2020-10-07    534.659973
# 2020-10-08    531.789978
# 2020-10-09    539.440002
#                  ...
# 2021-09-27    592.640015
# 2021-09-28    583.849976
# 2021-09-29    599.059998
# 2021-09-30    610.340027
# 2021-10-01    613.150024
# Name: Adj Close, Length: 251, dtype: float64

# %%
df2.to_excel('NFLX_df2.xlsx')

# %%
apple_path = "/content/AAPL.xlsx"
df3 = pd.read_excel(apple_path, index_col = 0)
df3.head()
df3.tail()
df3.shape
df4 = df3['Adj Close']
df4
# Out:
# Date
# 2022-10-03    141.609909
# 2022-10-04    145.238388
# 2022-10-05    145.536606
# 2022-10-06    144.572342
# 2022-10-07    139.263824
#                  ...
# 2023-09-25    176.080002
# 2023-09-26    171.960007
# 2023-09-27    170.429993
# 2023-09-28    170.690002
# 2023-09-29    171.210007
# Name: Adj Close, Length: 250, dtype: float64

# %%
df5 = pd.read_excel(path,index_col = 0,
                   sheet_name = 'NFLX_2')
df5.head

# %%
df6 = pd.read_excel(apple_path,index_col = 0,
                   sheet_name = 'Hoja1')
df6.head
# Out:
# <bound method NDFrame.head of              Adj Close     Volume
# Date
# 2022-10-03  141.609909  114311700
# 2022-10-04  145.238388   87830100
# 2022-10-05  145.536606   79471000
# 2022-10-06  144.572342   68402200
# 2022-10-07  139.263824   85925600
# ...                ...        ...
# 2023-09-25  176.080002   46172700
# 2023-09-26  171.960007   64588900
# 2023-09-27  170.429993   66921800
# 2023-09-28  170.690002   56294400
# 2023-09-29  171.210007   51814200
#
# [250 rows x 2 columns]>

# %%
df_ind30 = pd.read_csv('ind30_m_vw_rets.csv', index_col=0)
df_ind30.head()
df_ind30.columns
# Out:
# Index(['Food ', 'Beer ', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth ',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal ', 'Oil  ', 'Util ', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin  ', 'Other'],
#       dtype='object')

# %%
df_ind30_test = df_ind30[['Food ', 'Beer ', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth ',
       'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
       'Mines', 'Coal ', 'Oil  ', 'Util ', 'Telcm', 'Servs', 'BusEq', 'Paper',
       'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin  ']]

# %%
df_ind30_2 = pd.read_csv('ind30_m_vw_rets.csv', index_col=0, usecols=[1,2,3])
df_ind30_2.head()
# Out:
#        Beer   Smoke
# Food
#  0.56  -5.19   1.29
#  2.59  27.03   6.50
#  1.16   4.02   1.26
# -3.06  -3.31   1.06
#  6.35   7.29   4.55

# %%
df_amzn = pd.read_csv('AMZN.csv', index_col=0)
df_amzn.head(3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-03  113.580002  116.910004  112.449997  115.879997  115.879997
# 2022-10-04  119.889999  123.000000  119.790001  121.089996  121.089996
# 2022-10-05  118.580002  121.750000  117.690002  120.949997  120.949997
#
#               Volume
# Date
# 2022-10-03  50941900
# 2022-10-04  62812600
# 2022-10-05  48217500
